# %% [markdown]
# # Data Analysis - Movie Recommendation System
#
# This notebook focuses on initial data exploration, cleaning, and basic statistical analysis of the movie dataset.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import ast
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load Data

# %%
df = pd.read_csv('../../data/final/sample.csv')
df.head()
# Out:
#                                                title  \
# 0  Much Ado About Nothing: Shakespeare's Globe Th...
# 1                                       Piranhaconda
# 2                                       Edge of Fury
# 3                                   Bird of Paradise
# 4                        Critters 2: The Main Course
#
#                               genres  \
# 0                ['comedy', 'drama']
# 1               ['horror', 'sci-fi']
# 2                       ['thriller']
# 3  ['adventure', 'drama', 'romance']
# 4     ['comedy', 'horror', 'sci-fi']
#
#                                       positive_users  positive_count  \
# 0                                    [61947, 172263]               2
# 1                            [18184, 177617, 198781]               3
# 2                                                 []               0
# 3                                                 []               0
# 4  [1109, 1429, 6807, 36214, 48682, 49121, 52961,...              52
#
#                                       negative_users  negative_count  \
# 0                                                 []               0
# 1  [49217, 62537, 68978, 71504, 78715, 80729, 814...              22
# 2                                           [189614]               1
# 3                            [37118, 189614, 289344]               3
# 4  [1511, 2242, 2364, 4605, 4880, 5773, 6416, 793...             274
#
#    vote_average  vote_count    status release_date  revenue  runtime  adult  \
# 0         8.000           2  Released   2012-10-09        0      167  False
# 1         5.068         139  Released   2012-06-16        0       90  False
# 2         5.500           6  Released   1958-05-01        0       77  False
# 3         5.139          18  Released   1932-08-12   753000       80  False
# 4         5.957         370  Released   1988-04-29  3813293       86  False
#
#     budget original_language  \
# 0        0           English
# 1  1000000           English
# 2        0           English
# 3        0           English
# 4  4500000           English
#
#                                             overview  \
# 0  Much Ado About Nothing is a comedic play by Wi...
# 1  A hybrid creature - half piranha and half anac...
# 2  A psychopathic young beachcomber pretends to b...
# 3  When a young South Seas sailor falls overboard...
# 4  A batch of unhatched critter eggs are mistaken...
#
#                         poster_path        production_companies  \
# 0  /jkzvbyBQNo4NrLYtmllz6TIryJY.jpg         Shakespeare's Globe
# 1  /oqgQghwDwyv4PzyaoMUnhgtiCjt.jpg        New Horizons Picture
# 2  /A0C3I8F6PRim9FmCytNfP1RLouk.jpg        Wisteria Productions
# 3  /n2vjVQ1Y3m0LBTm59bYm1NfclqW.jpg          RKO Radio Pictures
# 4  /5rR3dVJXnXskkBBWKbLg5EDKWtT.jpg  Sho Films, New Line Cinema
#
#                                             keywords  tmdb_id
# 0                                       theater play   210695
# 1  ransom, hawaii, water monster, filmmaking, kil...   115084
# 2                                       summer house    35128
# 3             exotic island, volcano, love, pre-code    92341
# 4  spacecraft, small town, bounty hunter, hamburg...    10127

# %% [markdown]
# ## 3. Initial Exploration

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 15000 non-null  str
#  1   genres                15000 non-null  str
#  2   positive_users        15000 non-null  str
#  3   positive_count        15000 non-null  int64
#  4   negative_users        15000 non-null  str
#  5   negative_count        15000 non-null  int64
#  6   vote_average          15000 non-null  float64
#  7   vote_count            15000 non-null  int64
#  8   status                15000 non-null  str
#  9   release_date          15000 non-null  str
#  10  revenue               15000 non-null  int64
#  11  runtime               15000 non-null  int64
#  12  adult                 15000 non-null  bool
#  13  budget                15000 non-null  int64
#  14  original_language     15000 non-null  str
#  15  overview              15000 non-null  str
#  16  poster_path           15000 non-null  str
#  17  production_companies  15000 non-null  str
#  18  keywords              15000 non-null  str
#  19  tmdb_id               15000 non-null  int64
# dtypes: bool(1), float64(1), int64(7), str(11)
# memory usage: 2.2 MB

# %%
df.describe()
# Out:
#        positive_count  negative_count  vote_average    vote_count  \
# count    15000.000000    15000.000000  15000.000000  15000.000000
# mean       763.696467      251.449467      6.425128    801.752533
# std       3548.358195      794.137707      1.017764   2222.053151
# min          0.000000        0.000000      0.000000      0.000000
# 25%          2.000000        2.000000      5.800000     27.000000
# 50%         13.000000       12.000000      6.625000    105.000000
# 75%        174.000000      107.000000      7.100000    492.000000
# max      85220.000000    14719.000000     10.000000  34495.000000
#
#             revenue       runtime        budget       tmdb_id
# count  1.500000e+04  15000.000000  1.500000e+04  1.500000e+04
# mean   3.105401e+07    100.474933  1.057580e+07  1.802152e+05
# std    1.112583e+08     29.571787  2.782654e+07  2.245554e+05
# min    0.000000e+00      0.000000  0.000000e+00  3.000000e+00
# 25%    0.000000e+00     89.000000  0.000000e+00  1.820825e+04
# 50%    0.000000e+00     99.000000  0.000000e+00  6.158500e+04
# 75%    1.107246e+07    113.000000  7.456758e+06  3.082918e+05
# max    2.923706e+09    743.000000  3.790000e+08  1.136736e+06

# %% [markdown]
# ## 4. Missing Values Analysis

# %%
missing_values = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100
pd.concat([missing_values, missing_percent], axis=1, keys=['Missing Count', 'Percent'])
# Out:
#                       Missing Count  Percent
# title                             0      0.0
# genres                            0      0.0
# positive_users                    0      0.0
# positive_count                    0      0.0
# negative_users                    0      0.0
# negative_count                    0      0.0
# vote_average                      0      0.0
# vote_count                        0      0.0
# status                            0      0.0
# release_date                      0      0.0
# revenue                           0      0.0
# runtime                           0      0.0
# adult                             0      0.0
# budget                            0      0.0
# original_language                 0      0.0
# overview                          0      0.0
# poster_path                       0      0.0
# production_companies              0      0.0
# keywords                          0      0.0
# tmdb_id                           0      0.0

# %% [markdown]
# ## 5. Statistical Analysis of Numerical Columns

# %%
numerical_cols = ['vote_average', 'vote_count', 'revenue', 'runtime', 'budget']
df[numerical_cols].agg(['mean', 'median', 'std', 'min', 'max'])
# Out:
#         vote_average    vote_count       revenue     runtime        budget
# mean        6.425128    801.752533  3.105401e+07  100.474933  1.057580e+07
# median      6.625000    105.000000  0.000000e+00   99.000000  0.000000e+00
# std         1.017764   2222.053151  1.112583e+08   29.571787  2.782654e+07
# min         0.000000      0.000000  0.000000e+00    0.000000  0.000000e+00
# max        10.000000  34495.000000  2.923706e+09  743.000000  3.790000e+08

# %% [markdown]
# ## 6. Categorical Distribution

# %%
print("Language Distribution:")
print(df['original_language'].value_counts().head(10))

print("\nStatus Distribution:")
print(df['status'].value_counts())
# Out:
# Language Distribution:
# original_language
# English     10547
# French        742
# Japanese      558
# Spanish       390
# Italian       319
# German        313
# Korean        258
# Russian       246
# Hindi         235
# Chinese       185
# Name: count, dtype: int64
#
# Status Distribution:
# status
# Released    15000
# Name: count, dtype: int64
