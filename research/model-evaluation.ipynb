# %%
import os

os.chdir("../")
# %pwd
# Out:
# '/home/siddhu/Desktop/Movie-Recommendation-System'

# %%
import pickle
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
SAVED_EMBEDDING_PATH = "artifacts/model_trainer/movie_embeddings.pkl"
MOVIE_DATA_PATH = "artifacts/data_preparation/prepared.csv"

# %%
# Load the movie dataframe
df = pd.read_csv(MOVIE_DATA_PATH)
# Load the movie embedding
with open(SAVED_EMBEDDING_PATH, "rb") as f:
    movie_embedding = pickle.load(f)

# %%
def content_based_recommend(movie_title, df, embeddings=movie_embedding, N=12):
    idx = df[df["title"] == movie_title].index[0]
    movie_vec = embeddings[idx].reshape(1, -1)
    sims = cosine_similarity(movie_vec, embeddings).flatten()
    top_indices = sims.argsort()[::-1][1 : N + 1]
    return [(df.iloc[i]["title"], round(float(sims[i]), 3)) for i in top_indices]

# %%
movie_title = "Your Name."
result = content_based_recommend(
    movie_title=movie_title, df=df, embeddings=movie_embedding, N=12
)
result
# Out:
# [('Teasing Master Takagi-san: The Movie', 0.69),
#  ('As the Gods Will', 0.666),
#  ('Riding a Wave with You', 0.664),
#  ('Noblesse: Awakening', 0.655),
#  ('Twilight', 0.649),
#  ('School-Live!', 0.646),
#  ('The Boy and the Beast', 0.643),
#  ('Fruits Basket -prelude-', 0.64),
#  ('The Night Is Short, Walk on Girl', 0.637),
#  ('Letter to Momo, A (Momo e no tegami)', 0.637),
#  ('I Want to Deliver Your Voice', 0.634),
#  ('Her Blue Sky', 0.633)]
